# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('test.csv')
print(data)
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
plt.scatter(data.x,data.y)
plt.show()

# %%
def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0 
    b_gradient = 0

    n = len(points)

    for i in range(n):
        x = points.iloc[i].x
        y = points.iloc[i].y
        
        m_gradient += -(2/n) * x * (y - (m_now * x + b_now))
        b_gradient += -(2/n) * (y - (m_now * x + b_now))

    m = m_now - m_gradient * L
    b = b_now - b_gradient * L
    return m, b


m = 0 
b = 0 
L = 0.000001
epochs = 5000

for i in range(epochs):
    m, b = gradient_descent(m, b, data, L)

print(m, b)

plt.scatter(data.x, data.y,color="black")
x_value = list(range(0,110))
y_value = [m*x+b for x in x_value]

plt.plot(x_value, y_value, color="red",linewidth=2)
plt.show()
# Out:
# 1.007216548514357 0.013938338101224584
